# %% [markdown]
# <a href="https://colab.research.google.com/github/Sa-heed/Sa-heed/blob/main/Copy_of_Harmoye_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns


fuel_data = pd.read_csv("https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv")
fuel_data.head(10)
# fuel_data.iloc[0:3, 1:3]
# fuel_data.iloc[2, 5]


# fuel_data.shape
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
# 5  f1_fuel_1994_12_2_0_13  ...                1.850
# 6   f1_fuel_1994_12_2_1_1  ...                0.450
# 7  f1_fuel_1994_12_2_1_10  ...                2.360
# 8  f1_fuel_1994_12_2_2_10  ...                1.400
# 9   f1_fuel_1994_12_4_0_1  ...                1.278
#
# [10 rows x 11 columns]

# %%
fuel_data.iloc[0, 6]
fuel_data.loc[fuel_data.fuel_type_code_pudl=='nuclear'].count()
# Out:
# record_id                       818
# utility_id_ferc1                818
# report_year                     818
# plant_name_ferc1                818
# fuel_type_code_pudl             818
# fuel_unit                       818
# fuel_qty_burned                 818
# fuel_mmbtu_per_unit             818
# fuel_cost_per_unit_burned       818
# fuel_cost_per_unit_delivered    818
# fuel_cost_per_mmbtu             818
# dtype: int64

# %%
print(fuel_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB
# None

# %% [markdown]
# # Analyzing your data

# %%
plt.figure(figsize=(10, 4))
plt.xticks(rotation = 90)

# print(sns.countplot(x ='fuel_type_code_pudl', data =fuel_data ))
print(sns.countplot(x ='fuel_unit',  data =fuel_data ))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print('# the total number of utility id:'  +str(len(fuel_data.index)))
# Out:
# # the total number of utility id:29523

# %%
plt.figure(figsize=(10, 4))
plt.xticks(rotation = 90)

sns.countplot(x ='fuel_unit', data=fuel_data)

# %% [markdown]
# Checking for missing values

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %% [markdown]
# Checking the column with missing data for proper analysis

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
# Replace the missing column with the fuel unit that occurs most
fuel_data[['fuel_unit']]=fuel_data[['fuel_unit']].fillna(value ='mcf')

# %%
# Check if the missing data is filled
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
c = fuel_data.groupby('report_year')['report_year'].sum()
len(c)
c
fuel_data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  ...  fuel_cost_per_mmbtu
# fuel_type_code_pudl                          ...
# coal                  f1_fuel_1994_12_1_0_7  ...                1.121
# gas                  f1_fuel_1994_12_2_0_10  ...                2.570
# nuclear               f1_fuel_1994_12_2_1_1  ...                0.450
# oil                   f1_fuel_1994_12_6_0_2  ...                5.469
# other                f1_fuel_1994_12_11_0_6  ...                2.335
# waste                 f1_fuel_1994_12_9_0_3  ...                1.072
#
# [6 rows x 10 columns]

# %%
# Merging of data
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)
assert len(fuel_data)==(len(fuel_df1)  + len(fuel_df2))

# %%
# Merging the two data together(inner merge)
pd.merge(fuel_df1, fuel_df2, how = 'inner')
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
# merging the two data(outer merge)
pd.merge(fuel_df1, fuel_df2, how = 'outer')
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]

# %%
# merging the data(from left)
pd.merge(fuel_df1, fuel_df2, how = 'left')
# Out:
#                       record_id  ...  fuel_cost_per_mmbtu
# 0         f1_fuel_1994_12_1_0_7  ...                1.121
# 1        f1_fuel_1994_12_1_0_10  ...                1.120
# 2         f1_fuel_1994_12_2_0_1  ...                1.650
# 3         f1_fuel_1994_12_2_0_7  ...                1.970
# 4        f1_fuel_1994_12_2_0_10  ...                2.570
# ...                         ...  ...                  ...
# 18995   f1_fuel_2009_12_182_1_9  ...                4.711
# 18996  f1_fuel_2009_12_182_1_10  ...               14.634
# 18997  f1_fuel_2009_12_182_1_13  ...                1.107
# 18998  f1_fuel_2009_12_182_1_14  ...               15.102
# 18999    f1_fuel_2009_12_79_0_1  ...                1.727
#
# [19000 rows x 11 columns]

# %%
fuel_data.shape
# Out:
# (29523, 11)

# %%
# # merging the data(from right)
pd.merge(fuel_df1, fuel_df2, how = 'right')
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0       f1_fuel_2009_12_79_0_2  ...               11.341
# 1       f1_fuel_2009_12_79_0_4  ...                1.108
# 2       f1_fuel_2009_12_79_0_5  ...                6.238
# 3       f1_fuel_2009_12_79_0_7  ...                4.885
# 4      f1_fuel_2009_12_79_0_10  ...                5.383
# ...                        ...  ...                  ...
# 10518  f1_fuel_2018_12_12_0_13  ...                9.030
# 10519   f1_fuel_2018_12_12_1_1  ...                6.950
# 10520  f1_fuel_2018_12_12_1_10  ...                8.990
# 10521  f1_fuel_2018_12_12_1_13  ...                1.110
# 10522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [10523 rows x 11 columns]

# %%
# len(fuel_data)-len(a)

# %%
# Concatenation
pd.concat([fuel_df1, fuel_df2], axis=1).reset_index(drop=True)
# Out:
#                       record_id  ...  fuel_cost_per_mmbtu
# 0         f1_fuel_1994_12_1_0_7  ...               11.341
# 1        f1_fuel_1994_12_1_0_10  ...                1.108
# 2         f1_fuel_1994_12_2_0_1  ...                6.238
# 3         f1_fuel_1994_12_2_0_7  ...                4.885
# 4        f1_fuel_1994_12_2_0_10  ...                5.383
# ...                         ...  ...                  ...
# 18995   f1_fuel_2009_12_182_1_9  ...                  NaN
# 18996  f1_fuel_2009_12_182_1_10  ...                  NaN
# 18997  f1_fuel_2009_12_182_1_13  ...                  NaN
# 18998  f1_fuel_2009_12_182_1_14  ...                  NaN
# 18999    f1_fuel_2009_12_79_0_1  ...                  NaN
#
# [19000 rows x 22 columns]

# %%
# Check for duplicates rows
fuel_data.duplicated().sum()
duplicate = fuel_data[fuel_data.duplicated('fuel_type_code_pudl')]
duplicate
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 1       f1_fuel_1994_12_1_0_10  ...                 1.12
# 2        f1_fuel_1994_12_2_0_1  ...                 1.65
# 3        f1_fuel_1994_12_2_0_7  ...                 1.97
# 5       f1_fuel_1994_12_2_0_13  ...                 1.85
# 7       f1_fuel_1994_12_2_1_10  ...                 2.36
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                 9.03
# 29519   f1_fuel_2018_12_12_1_1  ...                 6.95
# 29520  f1_fuel_2018_12_12_1_10  ...                 8.99
# 29521  f1_fuel_2018_12_12_1_13  ...                 1.11
# 29522  f1_fuel_2018_12_12_1_14  ...                11.68
#
# [29517 rows x 11 columns]

# %%
fuel_data.columns
# fuel_unit

fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11534
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %% [markdown]
# Visualization

# %%
# import plotiing library
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit': ['bbl','gal', 'gramsU', 'kgU ', 'mcf', 'mmbtu', 'mwdth', 'mwhth','ton'],'count': [7998, 84, 464, 110, 11534, 180, 95, 100, 8958]})
sns.barplot(data= fuel_unit, x ='unit', y='count')
plt.xlabel('fuel_unit')
plt.ylabel('count_unit')

# because of the extreme value of y,we can take logarithm of y
# q =sns.barplot(data = fuel_unit, x = 'unit', y='count' )
# q.set_yscale('log')
# q.set_ylim(1, 12000)
# plt.xlabel('fuel_unit')
# Out:
# Text(0, 0.5, 'count_unit')

# %%
fuel_data.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
# selecting sample of dataset
sample = fuel_data.sample(n=50,random_state=7)
sns.regplot(x = sample['utility_id_ferc1'], y=sample['fuel_cost_per_mmbtu'], fit_reg=False)

# %%
sns.boxplot(x='fuel_type_code_pudl',y='utility_id_ferc1', palette =['k','b'], data=fuel_data)

# %%
# KDE Plot
sns.kdeplot(sample['fuel_cost_per_unit_burned'], shade = True, color = 'b')
